# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import statsmodels.api as sm

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# special matplotlib argument for improved plots
from matplotlib import rcParams

# %%
parts_cost = pd.read_csv(
    'C:/Users/502689880/GE Projects/Parts_Cost/Level_1_data.csv')

parts_cost.head()
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (8,19,44,45,50,51,52,53,54,58,61,72,79,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         EBOM L1# present at L1 Part Number EBOM Top Parent #  Parent MLI  \
# 0  111T2003G0001    Level 1  111T2003G0001      367A7114G002         NaN
# 1  114T9285G0001    Level 1  114T9285G0001      367A6734G025         NaN
# 2  112L1003G0005    Level 1  112L1003G0005      367A7111G028         NaN
# 3  112L1003G0005    Level 1  112L1003G0005      367A7111G028         NaN
# 4   813L2181G074    Level 1   813L2181G074      367A5800G007         NaN
#
#      BOM UOM  Total Lead Time  Zero   MLI  display        ...         \
# 0  EA (each)              NaN     0  0002  Level 1        ...
# 1  EA (each)              NaN     0  0014  Level 1        ...
# 2  EA (each)              NaN     0  0100  Level 1        ...
# ...

# %%
parts_cost.columns = ['ebomL1', 'presentAt', 'partNumberL1', 'tParent', 'parentMLI', 'bomUoM', 'totalLeadTime', 'zero', 'task', 
                      'display', 'partNumberSelect', 'dimLeadTime', 'calculation1', 'calculation2', 'partNumCal', 'calculation3', 
                      'inventoryItemCost', 'itemBoMItemType', 'familyCode', 'frameSize', 'postProcLeadTime', 'preProcLeadTime', 
                      'procLeadTime', 'itemMaterialCost', 'erpPartNumber', 'itemPrimaryUoM', 'partStatus', 
                      'itemWarehouseOnhandAvailableQty', 'itemWarehouseReservationQty', 'itemWarehouseTransactionQty', 
                      'numberOfRecords', 'servigisticsPartActive', 'servigisticsPartClass', 'servigisticsPartDesc', 
                      'servigisticsPartFamilyName', 'servigisticsPartGECost', 'servigisticsPartID', 'servigisticsPartName', 
                      'servigisticsPartNumber', 'servigisticsPartPC3SMIFlag', 'servigisticsPartStatus', 'bomQty', 'origBoMUoM', 
                      'level0', 'level10', 'level11', 'level1', 'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 
                      'level8', 'level9', 'ebomPartNum', 'ebomDFSOrder', 'erpCurrency', 'erpUoM', 'excessFw47', 'excessOverall', 
                      'forecastPolicy', 'internalPOCurrency', 'internalPODescription', 'internalPOOrderCost', 
                      'internalPOQuantity', 'internalPOUnitCost', 'internalPOUoM', 'itemCost', 'itemNumber', 'dbLeadTime', 
                      'ebomLvl', 'sourceMLI', 'onHand', 'onHandInventory', 'openPOSTotal', 'openSOSTotal', 'ebomParentNum', 
                      'itemDescription', 'phase1Or2', 'pin', 'qtySet', 'relationID', 'repeatOrCampaignSpecific', 
                      'soItemDescription', 'soOrderQuantity', 'soUnitCost', 'ebomTopParentName', 'totalFcst12016', 
                      'totalfcst2016', 'venPOCurrencyCode', 'vendorPOItemDescription', 'venPOLeadTime', 'venPOOrderedQuantity', 
                      'VenPOUnitPrice']

parts_cost.head()
# Out:
#           ebomL1 presentAt   partNumberL1       tParent  parentMLI     bomUoM  \
# 0  111T2003G0001   Level 1  111T2003G0001  367A7114G002        NaN  EA (each)
# 1  114T9285G0001   Level 1  114T9285G0001  367A6734G025        NaN  EA (each)
# 2  112L1003G0005   Level 1  112L1003G0005  367A7111G028        NaN  EA (each)
# 3  112L1003G0005   Level 1  112L1003G0005  367A7111G028        NaN  EA (each)
# 4   813L2181G074   Level 1   813L2181G074  367A5800G007        NaN  EA (each)
#
#    totalLeadTime  zero  task  display      ...       soOrderQuantity  \
# 0            NaN     0  0002  Level 1      ...                   NaN
# 1            NaN     0  0014  Level 1      ...                   NaN
# 2            NaN     0  0100  Level 1      ...                   NaN
# 3            NaN     0  0100  Level 1      ...                   NaN
# 4            NaN     0  0106  Level 1      ...                   NaN
#
#    soUnitCost ebomTopParentName totalFcst12016 totalfcst2016  \
# ...

# %%
parts_cost.dtypes
# Out:
# ebomL1                              object
# presentAt                           object
# partNumberL1                        object
# tParent                             object
# parentMLI                          float64
# bomUoM                              object
# totalLeadTime                      float64
# zero                                 int64
# task                                object
# display                             object
# partNumberSelect                    object
# dimLeadTime                        float64
# calculation1                        object
# calculation2                        object
# partNumCal                          object
# calculation3                         int64
# inventoryItemCost                  float64
# itemBoMItemType                    float64
# familyCode                          object
# frameSize                           object
# postProcLeadTime                   float64
# preProcLeadTime                    float64
# ...

# %%
parts_cost.shape
# Out:
# (1185193, 95)

# %%
parts_cost.columns
# Out:
# Index(['ebomL1', 'presentAt', 'partNumberL1', 'tParent', 'parentMLI', 'bomUoM',
#        'totalLeadTime', 'zero', 'task', 'display', 'partNumberSelect',
#        'dimLeadTime', 'calculation1', 'calculation2', 'partNumCal',
#        'calculation3', 'inventoryItemCost', 'itemBoMItemType', 'familyCode',
#        'frameSize', 'postProcLeadTime', 'preProcLeadTime', 'procLeadTime',
#        'itemMaterialCost', 'erpPartNumber', 'itemPrimaryUoM', 'partStatus',
#        'itemWarehouseOnhandAvailableQty', 'itemWarehouseReservationQty',
#        'itemWarehouseTransactionQty', 'numberOfRecords',
#        'servigisticsPartActive', 'servigisticsPartClass',
#        'servigisticsPartDesc', 'servigisticsPartFamilyName',
#        'servigisticsPartGECost', 'servigisticsPartID', 'servigisticsPartName',
#        'servigisticsPartNumber', 'servigisticsPartPC3SMIFlag',
#        'servigisticsPartStatus', 'bomQty', 'origBoMUoM', 'level0', 'level10',
# ...

# %%
parts_cost.qtySet.describe()
# Out:
# count    14441.000000
# mean       117.651894
# std        134.965241
# min          1.000000
# 25%         14.000000
# 50%         14.000000
# 75%        280.000000
# max        770.000000
# Name: qtySet, dtype: float64

# %%
parts_cost_subset = ['tParent', 'ebomL1', 'ebomPartNum', 'presentAt', 'itemMaterialCost', 'bomQty']
parts_cost_sub1 = parts_cost[parts_cost_subset]
parts_cost_sub1
# Out:
#                tParent         ebomL1       ebomPartNum presentAt  \
# 0         367A7114G002  111T2003G0001     111T2003G0001   Level 1
# 1         367A6734G025  114T9285G0001     114T9285G0001   Level 1
# 2         367A7111G028  112L1003G0005     112L1003G0005   Level 1
# 3         367A7111G028  112L1003G0005     112L1003G0005   Level 1
# 4         367A5800G007   813L2181G074      813L2181G074   Level 1
# 5         367A5800G007   813L2181G074      813L2181G074   Level 1
# 6         367A5800G007   813L2181G074      813L2181G074   Level 1
# 7         367A5800G007   813L2181G074      813L2181G074   Level 1
# 8         367A5800G007   813L2181G074      813L2181G074   Level 1
# 9         367A6414G006   813L2181G074      813L2181G074   Level 1
# 10        367A6414G006   813L2181G074      813L2181G074   Level 1
# 11        367A6414G006   813L2181G074      813L2181G074   Level 1
# 12        367A7309G001  110T5502G0001     110T5502G0001   Level 1
# ...

# %%
parts_cost_sub1['totalCost'] = parts_cost_sub1.itemMaterialCost * parts_cost_sub1.bomQty
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
parts_cost_sub1
# Out:
#                tParent         ebomL1       ebomPartNum presentAt  \
# 0         367A7114G002  111T2003G0001     111T2003G0001   Level 1
# 1         367A6734G025  114T9285G0001     114T9285G0001   Level 1
# 2         367A7111G028  112L1003G0005     112L1003G0005   Level 1
# 3         367A7111G028  112L1003G0005     112L1003G0005   Level 1
# 4         367A5800G007   813L2181G074      813L2181G074   Level 1
# 5         367A5800G007   813L2181G074      813L2181G074   Level 1
# 6         367A5800G007   813L2181G074      813L2181G074   Level 1
# 7         367A5800G007   813L2181G074      813L2181G074   Level 1
# 8         367A5800G007   813L2181G074      813L2181G074   Level 1
# 9         367A6414G006   813L2181G074      813L2181G074   Level 1
# 10        367A6414G006   813L2181G074      813L2181G074   Level 1
# 11        367A6414G006   813L2181G074      813L2181G074   Level 1
# 12        367A7309G001  110T5502G0001     110T5502G0001   Level 1
# ...

# %%
parts_cost_total = parts_cost_sub1.groupby(['tParent','ebomL1'], as_index=False).totalCost.sum()
parts_cost_total
# Out:
#             tParent         ebomL1     totalCost
# 0      367A1234G008  111T2084G0001  3.886415e+03
# 1      367A1234G008  112T7022P0106  1.660000e+04
# 2      367A1234G008  121T9619G0004  5.636867e+03
# 3      367A1234G008   146E2580G014  2.073125e+04
# 4      367A1234G008   356B2202G017  2.003255e+05
# 5      367A1234G008   362A1987G001  8.425062e+02
# 6      367A1234G008   389A4104P001  5.398470e+03
# 7      367A1234G567   102T2488G001  1.660633e+03
# 8      367A1234G567  120T8158G0001  5.265526e+05
# 9      367A1234G567  120T8161G0001  3.203017e+05
# 10     367A1234G567  398A5548G0001  1.530786e+04
# 11     367A3016G001   362A2202P001  2.149652e+04
# 12     367A3046G001   224B9190G002  2.633667e+01
# 13     367A3059G001   224B9190G001  1.266667e+01
# 14     367A3059G001   324A3989G002  1.022550e+05
# 15     367A3059G002   224B9190G001  1.266667e+01
# 16     367A3059G002   324A3989G002  1.022550e+05
# 17     367A3066G001   104L4736G003  4.237787e+03
# ...

# %%
parts_cost_total.to_csv('parts_cost_total.csv', index=False)
print('Done')
# Out:
# Done
